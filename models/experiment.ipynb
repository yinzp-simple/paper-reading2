# %%
import numpy as np
import matplotlib.pyplot as plt
def draw_loss(filepath):
    import matplotlib.pyplot as plt
    loss_list = list(np.load(filepath))
    plt.plot(list(range(1, len(loss_list) + 1)), loss_list)

# %% [markdown]
# # 其他试验

# %% [markdown]
# ## 实验-1
# 损失函数：$loss = loss_{one-hot}  + loss_{information-entropy} * 5 + loss_{active} * 0.1 + loss_{kd}$
#
# 生成器优化器：Adam(lr = 0.2)
#
# lr_scheduler：CosineAnnealingWarm(T_0 = 5, T_mult = 2)
#
# 学生网络优化器：Adam(lr = 2e-3)
#
# lr_scheduler：CosineAnnealingWarm(T_0 = 5, T_mult = 2
#
# epoch = 100
#
# oh = 1, ie = 5, a = 0.1

# %%
draw_loss('cache/models//student_epoch_100.npy')

# %% [markdown]
# ## 试验-2
# 加了个硬损失loss_kd_h = self.criterion(self.student(gen_img.detach()), pseudo_labels)
#
# loss = loss_onehot * self.oh + loss_information_entropy * self.ie + loss_active * self.a + loss_kd + loss_kd_h

# %%
draw_loss('cache/models/student/student_epoch_200.npy')

# %% [markdown]
# # DFAD试验记录

# %% [markdown]
# ## mnist

# %% [markdown]
# epochs=40,bs=512,epoch_itrs=50
#
# 教师网络：
# * LeNet5
# * 准确率：99.24%
#
# 学生网络：
# * LeNet5Half
# * 准确率：94.01%(epoch=20),92.83%,91.89%,89.95%,95.71%
# * 损失：F.l1_loss()
# * SGD(lr=0.01, weight_decay=1e-4, momentum=0.9)
#
# 生成器：
# * GenerarorA
# * 损失：-F.l1_loss()
# * Adam(lr=1e-3)

# %%
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/LeNet5Half_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/GeneratorA_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/2LeNet5Half_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/2GeneratorA_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/3LeNet5Half_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/3GeneratorA_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/4LeNet5Half_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/4GeneratorA_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/5LeNet5Half_loss_40.npy")
draw_loss("/home/ubuntu/YZP/gitee/models/ckpt/5GeneratorA_loss_40.npy")

# %% [markdown]
# epochs=40,bs=512,epoch_itrs=50
#
# 教师网络：
# * LeNet5
# * 准确率：99.24%
#
# 学生网络：
# * LeNet5Half
# * 准确率：94.01%(epoch=20),92.83%,91.89%,89.95%,95.71%
# * 损失：F.l1_loss()
# * SGD(lr=0.01, weight_decay=1e-4, momentum=0.9)
# *
#
# 生成器：
# * GenerarorA
# * 损失：-F.l1_loss()
# * Adam(lr=1e-3)
